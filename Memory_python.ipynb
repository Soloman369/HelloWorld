# %%
mylist = [1,2,3]
print(id(mylist))

mylist_copy2 = list(mylist)
print(id(mylist_copy2))

mylist_copy = mylist
print(id(mylist_copy))
# Out:
# 4506032008
# 4506684488
# 4506032008

# %%
mylist
del mylist[1:]
mylist.append(25)
print(mylist)
print(mylist_copy)
print(mylist_copy2)
# Out:
# [1, 25]
# [1, 25]
# [1, 2, 3]
