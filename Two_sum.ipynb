# %%
nums = [2,7,11,15]


target = 9
done = False
for i in nums:
    for y in nums:
        if i + y == target:
            print("Because nums[",i,"] + nums[",y,"] = ",i, "+",y," =",target,",\n return [",i,",",y, "]"  )
        break
# Out:
# Because nums[ 7 ] + nums[ 2 ] =  7 + 2  = 9 ,
#  return [ 7 , 2 ]
