# %%
import numpy as np

# %%
from PIL import Image
pil_im = Image.open('python_jpg.jpg', 'r')
#.save('result.png')
#size = 225 , 122
#pil_im = pil_im.resize(size)
#pil_im = pil_im.convert('1')
#pil_im = pil_im.rotate(180)
#pil_im

# %%
x = np.array(pil_im)
#print(x[:10,:10,:])
#print(x[:2,:2,:])
x[:50,:50] = 0
from PIL import Image
new_pil_im = Image.fromarray(x)
new_pil_im
# Out:
# <PIL.Image.Image image mode=RGB size=450x253 at 0x11A1BA128>
