# %%
import random

class des:
    def __init__(self , faces):
        self.faces = faces
    def lancer(self):
        print(random.choice(range(1,7)))
    
lancer = des(range(1,7))
lancer.lancer()
# Out:
# 1
